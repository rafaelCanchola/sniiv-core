# %%
import pandas as pd
tabla_principal = 'join.csv'
tabla_foranea = 'foreign.csv'
tabla_orden = 'columns.csv'

tabla1 = pd.read_csv(tabla_principal)
foranea = pd.read_csv(tabla_foranea)
columnas = pd.read_csv(tabla_orden)
tabla2 = tabla1.merge(foranea, how="left", on=["NOM_CAMP","NOM_TABLA"], )
tabla3 = tabla2.merge(columnas[['NOM_CAMP','NOM_TABLA',O]],how="left",on=["NOM_CAMP","NOM_TABLA"], )
tabla3
# Out:
#                   NOM_TABLA                  NOM_CAMP  TIPO TAMAÑO      CLAVE  \
# 0                banjercito                        id   INT    NaN  principal
# 1                banjercito  clave_entidad_federativa  CHAR      2    Foranea
# 2                banjercito           clave_municipio  CHAR      3    Foranea
# 3                banjercito          id_linea_credito   INT    NaN    Foranea
# 4                banjercito                  producto  ENUM    NaN    Interna
# ...                     ...                       ...   ...    ...        ...
# 1090  subprograma_fovissste                id_esquema   INT    NaN    foranea
# 1091  subprograma_fovissste          id_linea_credito   INT    NaN    foranea
# 1092  subprograma_fovissste              id_modalidad   INT    NaN    Foranea
# 1093  subprograma_fovissste            id_subprograma   INT    NaN    foranea
# 1094  subprograma_fovissste           id_tipo_credito   INT    NaN    foranea
#
#                        FOR_TABLA TABLE_CATALOG TABLE_SCHEMA  ORDINAL_POSITION  \
# 0                            NaN           def        sniiv               1.0
# 1           c_entidad_federativa           def        sniiv               2.0
# 2                            NaN           def        sniiv               3.0
# 3     c_linea_credito_banjercito           def        sniiv               4.0
# 4                            NaN           def        sniiv               5.0
# ...                          ...           ...          ...               ...
# 1090         c_esquema_fovissste           def        sniiv               2.0
# 1091   c_linea_credito_fovissste           def        sniiv               3.0
# 1092       c_modalidad_fovissste           def        sniiv               4.0
# 1093               c_subprograma           def        sniiv               5.0
# 1094              c_tipo_credito           def        sniiv               6.0
#
#      COLUMN_DEFAULT  ... DATETIME_PRECISION CHARACTER_SET_NAME  \
# 0               NaN  ...                NaN                NaN
# 1               NaN  ...                NaN               utf8
# 2               NaN  ...                NaN               utf8
# 3               NaN  ...                NaN                NaN
# 4               NaN  ...                NaN               utf8
# ...             ...  ...                ...                ...
# 1090            NaN  ...                NaN                NaN
# 1091            NaN  ...                NaN                NaN
# 1092            NaN  ...                NaN                NaN
# 1093            NaN  ...                NaN                NaN
# 1094            NaN  ...                NaN                NaN
#
#        COLLATION_NAME                                     COLUMN_TYPE  \
# 0                 NaN                                    int unsigned
# 1     utf8_spanish_ci                                         char(2)
# 2     utf8_spanish_ci                                         char(3)
# 3                 NaN                                    int unsigned
# 4     utf8_spanish_ci  enum('Crédito hipotecario','Crédito liquidez')
# ...               ...                                             ...
# 1090              NaN                                    int unsigned
# 1091              NaN                                    int unsigned
# 1092              NaN                                    int unsigned
# 1093              NaN                                    int unsigned
# 1094              NaN                                    int unsigned
#
#       COLUMN_KEY  EXTRA                       PRIVILEGES COLUMN_COMMENT  \
# 0            PRI    NaN  select,insert,update,references            NaN
# 1            MUL    NaN  select,insert,update,references            NaN
# 2            NaN    NaN  select,insert,update,references            NaN
# 3            MUL    NaN  select,insert,update,references            NaN
# 4            NaN    NaN  select,insert,update,references            NaN
# ...          ...    ...                              ...            ...
# 1090         MUL    NaN  select,insert,update,references            NaN
# 1091         MUL    NaN  select,insert,update,references            NaN
# 1092         MUL    NaN  select,insert,update,references            NaN
# 1093         MUL    NaN  select,insert,update,references            NaN
# 1094         MUL    NaN  select,insert,update,references            NaN
#
#      GENERATION_EXPRESSION SRS_ID
# 0                      NaN    NaN
# 1                      NaN    NaN
# 2                      NaN    NaN
# 3                      NaN    NaN
# 4                      NaN    NaN
# ...                    ...    ...
# 1090                   NaN    NaN
# 1091                   NaN    NaN
# 1092                   NaN    NaN
# 1093                   NaN    NaN
# 1094                   NaN    NaN
#
# [1095 rows x 26 columns]
